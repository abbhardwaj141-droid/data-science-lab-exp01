# %% [markdown]
# <a href="https://colab.research.google.com/github/abbhardwaj141-droid/data-science-lab-exp01/blob/main/Pandas_Data_Frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas DataFrames - Lab Practice Sheet

# %%
##Q.1
import pandas as pd
import numpy as np

data = {
    'Name': ['Aman', 'Ravi', 'Neha', 'Priya'],
    'Age': [20, 21, 19, 22],
    'City': ['Delhi', 'Mumbai', 'Pune', 'Agra']
}

student_df = pd.DataFrame(data)

# %%
##Q.2
print(student_df)

# %%
##Q.3
print(student_df.columns)

# %%
##Q.4
student_df['Name']

# %%
##Q.5
student_df['City']

# %%
##Q.6
new_df = student_df[['Name', 'City']]
print(new_df)

# %%
##Q.7
data = {
    'Book': ['Python', 'Java', 'C++'],
    'Author': ['A', 'B', 'C'],
    'Price': [400, 500, 350]
}

book_df = pd.DataFrame(data)

# %%
##Q.8
book_df['Publisher'] = 'ABC Publishers'

# %%
##Q.9
df = pd.DataFrame({
    'Name': ['A', 'B', 'C', 'D', 'E']
})

df['SerialNo'] = np.arange(5)

print(df)

# %%
##Q.10
del df['SerialNo']

# %%
##Q.11
movie_df = pd.DataFrame({
    'Movie': ['Dangal', 'PK', '3 Idiots'],
    'Year': [2016, 2014, 2009],
    'Rating': [9.0, 8.5, 9.2]
})

# %%
##Q.12
new_movie_df = movie_df[['Movie', 'Rating']].copy()

new_movie_df['Director'] = ['Nitesh', 'Rajkumar', 'Rajkumar']

print(new_movie_df)

# %%
##Q.13
cities = pd.Series(
    ['Delhi', 'Mumbai'],
    index=[0, 3]
)

# %%
##Q.14
df = pd.DataFrame({
    'Name': ['A', 'B', 'C', 'D']
})

df['Branch'] = cities

print(df)

# %%
##Q.15
copied_df = pd.read_clipboard()

print(copied_df)

# %%
##Q.16
employee_df = pd.DataFrame({
    'Employee': ['Aman', 'Ravi', 'Neha', 'Priya', 'Rahul'],
    'Department': ['IT', 'HR', 'Sales', 'IT', 'Finance'],
    'Experience': [2, 4, 3, 5, 1]
})

new_df = employee_df[['Employee', 'Experience']]

print(new_df)

# %%
##Q.17
employee_df['Department']
employee_df.columns

# %%
##Q.18
employee_df['Office'] = 'Head Office'

print(employee_df)

# %%
##Q.19
employee_df['Office'] = np.arange(5)

print(employee_df)

# %%
##Q.20
office_names = pd.Series(
    ['Delhi', 'Mumbai', 'Pune'],
    index=[0, 2, 4]
)

employee_df['Office'] = office_names

print(employee_df)

# %%
##Q.21
del employee_df['Office']

print(employee_df)

# %%
##Q.22
product_df = pd.DataFrame({
    'Product': ['Pen', 'Book', 'Bag'],
    'Category': ['Stationery', 'Stationery', 'Travel'],
    'Price': [10, 50, 700]
})

new_product_df = product_df[['Price', 'Product', 'Category']]

print(new_product_df)

# %%
##Q.23
data = {
    'Name': ['A', 'B', 'C'],
    'Age': [20, 21, 22]
}

df = pd.DataFrame(
    data,
    columns=['Name', 'Age', 'City']
)

print(df)

# %%
##Q.24
df = pd.DataFrame({
    'Name': ['A', 'B', 'C'],
    'Total Marks': [80, 90, 75]
})
df['Total Marks']

# %%
##Q.25
df = pd.read_clipboard()

print(df.columns)

new_df = df[['Name', 'Age', 'City']]

print(new_df)

# %%
##Q.26
course_df = pd.DataFrame({
    'Student': ['Aman', 'Ravi', 'Neha', 'Priya', 'Rahul'],
    'Course': ['Python', 'Java', 'DBMS', 'CN', 'OS'],
    'Score': [85, 78, 90, 72, 88]
})

# %%
##Q.26.A
print(course_df.columns)

# %%
##Q.26.B
print(course_df['Student'])

# %%
##Q.26.C
new_df = course_df[['Student', 'Score']]

print(new_df)

# %%
##Q.26.D
course_df['Batch'] = 'B1'

print(course_df)

# %%
##Q.27
travel_df = pd.DataFrame({
    'Place': ['Delhi', 'Agra', 'Jaipur', 'Pune', 'Mumbai']
})

# %%
##Q.28
school_df = pd.DataFrame({
    'Student': ['Aman', 'Ravi', 'Neha', 'Priya'],
    'Class': [10, 10, 11, 11],
    'Section': ['A', 'B', 'A', 'B']
})
new_df = school_df[
    ['Student', 'Class', 'Section', 'House']
]
new_df['House'] = 'Red'

print(new_df)

# %%
##Q.29
inventory_df = pd.DataFrame({
    'Item': ['Pen', 'Book', 'Bag', 'Pencil'],
    'Quantity': [50, 30, 20, 80]
})
stock = pd.Series(
    [100, 200],
    index=[0, 2]
)
inventory_df['Stock'] = stock

print(inventory_df)

# %%
##Q.30
lab_df = pd.read_clipboard()
print(lab_df)
print(lab_df.columns)
print(lab_df['Name'])
print(lab_df['Total Marks'])
small_df = lab_df[['Name', 'City', 'Total Marks']]

print(small_df)
lab_df['Country'] = 'India'

print(lab_df)
del lab_df['Country']

print(lab_df)
